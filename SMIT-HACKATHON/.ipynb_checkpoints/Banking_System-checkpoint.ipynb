# %%
# Banking system project using functional programming
import random
def create_account(accounts):
    account_details = {"account_number":"","account_title":"","balance":0.0,"transactions":[]}
    create_name = True
    while create_name:
        try:
            
            first_name = input("Please enter your first name")
            if first_name == "":
                raise Exception("Input Is Empty. Please make sure you have entered your name.")
            elif first_name.isalpha():
                account_title = first_name
            else:
                raise Exception("Digits and Speacial Characters are not allowed in name")
            
            last_name = input("Please enter your last name")

            if last_name == "":
                raise Exception("Input Is Empty. Please make sure you have entered your name.")
            elif last_name.isalpha():
                account_title = f"{first_name} {last_name}"
                account_details["account_title"] = account_title 
            else:
                raise Exception("Digits and speacial characters are not allowed in name")
            create_name =  False
        except Exception as e:
            print(e)
    create_pin = True
    while create_pin:
        try:
            pin = input("Please enter a 4 digit pin.")

            if pin == "":
                raise Exception("Input is empty. Please make sure you have enter a pin.")
            elif pin.isdigit():
                pin = int(pin)
                accounts[pin] = pin
                create_pin = False
            else:
                raise Exception("Letters and Characters are not allowed.")
        except Exception as e:
            print(e)

    account_number = random.randint(1000,9999)
    account_details["account_number"] = account_number
    accounts[pin] = account_details

def deposit_money():
    print("working")

def withdraw_money():
    print("working")

def check_balance():
    print("working")

def print_statement():
    print("working")

def load_accounts():
    print("working")

def save_accounts():
    print("working")

def total_deposits():
    print("working")

def total_accounts():
    print("working")

# displaying main menu
def main_menu():

    begin = True
    while begin:
        # asking user for input to show either administration menu or user menu
        print("Press 1 for administration menu: ")
        print("Press 2 for user menu:")

        # using try except block to catch potential errors
        try:
                
            user_input = input("Please enter a digit")
            if user_input == "": # checking if user input is empty
                raise Exception("Input Is Empyt! Please Enter A Number.")
            elif user_input not in ("1","2"): # checking if user input is valid
                raise Exception("Wrong Input! Please enter 1 or 2.")

            # displaying the administration menu options 
            if user_input == "1":
                print("1. Check Total Deposits.")
                print("2. Check Total Accounts.")
                print("Press 3 to return to main menu")
                user_choice = input("Please enter a number to select an option")

                if user_choice == "":
                    raise Exception("Input IS Empty! Please enter a number")
                elif user_choice not in ("1","2","3"):
                    raise Exception("Wrong Input! Please enter a digit between 1 to 3")

                
                if user_choice == "1":
                    total_deposits()
                elif user_choice == "2":
                    total_accounts()
                else:
                    main_menu()
            else:
                print("1. Create Account.")
                print("2. Deposit Money.")
                print("3. Withdraw Money.")
                print("4. Check Balance.")
                print("5. Print Statement.")
                print("6. Exit")
    
                user_choice = input("Please Enter A Digit To Select An Option.")

                if user_choice == "":
                    raise Exception("Input IS Empty! Please enter a number")
                elif user_choice not in ("1","2","3","4","5","6"):
                    raise Exception("Wrong Input! Please enter a digit between 1 to 6")

                
                if user_choice == "1":
                    create_account(accounts)
                elif user_choice == "2":
                    deposit_money()
                elif user_choice == "3":
                    withdraw_money()
                elif user_choice == "4":
                    check_balance()
                elif user_choice == "5":
                    print_statement()
                else:
                    begin = False
        except Exception as e:
            print(e)
        
        begin = False
accounts = {"pin"}
print(accounts)
main_menu()
# Out:
# {'pin'}
# Press 1 for administration menu:
# Press 2 for user menu:
# Please enter a digit 2
# 1. Create Account.
# 2. Deposit Money.
# 3. Withdraw Money.
# 4. Check Balance.
# 5. Print Statement.
# 6. Exit
# Please Enter A Digit To Select An Option. 1
# Please enter your first name sufyan
# Please enter your last name rahman
# Please enter a 4 digit pin. 1111
# 'set' object does not support item assignment
